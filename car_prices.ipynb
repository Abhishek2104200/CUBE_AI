# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishek2104200/CUBE_AI/blob/main/car_prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import io

# %%
from sklearn.datasets import make_classification
x,y=make_classification(n_samples = 80, n_features=2,n_redundant=0,n_informative=2,n_repeated=0,n_classes =3,n_clusters_per_class=1)
plt.scatter(x[:,0],x[:,0],c=y)
plt.show()

# %%
display(data.head())
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %% [markdown]
# Number of columns

# %%
data.shape[1]
# Out:
# 16

# %% [markdown]
# Number of Row

# %%
data.shape[0]
# Out:
# 558837

# %%
data
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
x=data['sellingprice']
y=data['year']
plt.plot(x,y)

# %%
plt.plot(y)

# %%
for chunk in data:
    display(chunk.head())
    break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 for chunk in data:
# ----> 2     display(chunk.head())
#       3     break
#
# AttributeError: 'str' object has no attribute 'head'

# %%
data
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
df=pd.read_csv("C:\intern\car_prices.csv",chunksize=100000)

# %%
for chunk in df:
    display(chunk.head())
    break
# Out:
#    year       make     model                       trim         body  \
# 0  2015     Nissan    Altima                      2.5 S        Sedan
# 1  2014       Audi        Q5  2.0T Premium Plus quattro          SUV
# 2  2014  Chevrolet    Camaro                         LS        Coupe
# 3  2014        BMW  6 Series                       650i  Convertible
# 4  2015  Chevrolet    Impala                        LTZ        Sedan
#
#   transmission                vin state  condition  odometer   color interior  \
# 0    automatic  1n4al3ap5fc124223    ca          2     11398   black    black
# 1    automatic  wa1lfafpxea085074    ca         49      7983   white    black
# 2    automatic  2g1fa1e39e9134494    ca         17     13441   black    black
# 3    automatic  wbayp9c53ed169260    ca         34      8819   black    black
# 4    automatic  2g1165s30f9103921    ca         19     14538  silver    black
#
#                                               seller    mmr  sellingprice  \
# ...

# %%
data
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %% [markdown]
# TASK

# %%
data=pd.read_csv("C:\intern\car_prices.csv")
data.head()
# Out:
#    year       make     model                       trim         body  \
# 0  2015     Nissan    Altima                      2.5 S        Sedan
# 1  2014       Audi        Q5  2.0T Premium Plus quattro          SUV
# 2  2014  Chevrolet    Camaro                         LS        Coupe
# 3  2014        BMW  6 Series                       650i  Convertible
# 4  2015  Chevrolet    Impala                        LTZ        Sedan
#
#   transmission                vin state  condition  odometer   color interior  \
# 0    automatic  1n4al3ap5fc124223    ca          2     11398   black    black
# 1    automatic  wa1lfafpxea085074    ca         49      7983   white    black
# 2    automatic  2g1fa1e39e9134494    ca         17     13441   black    black
# 3    automatic  wbayp9c53ed169260    ca         34      8819   black    black
# 4    automatic  2g1165s30f9103921    ca         19     14538  silver    black
#
#                                               seller    mmr  sellingprice  \
# ...

# %%
x=pd.DataFrame(data)
x.describe()
# Out:
#                 year      condition       odometer            mmr  \
# count  472311.000000  472311.000000  472311.000000  472311.000000
# mean     2010.210853      30.774403   66703.403433   13836.580399
# std         3.822135      13.286546   51939.434461    9531.478251
# min      1990.000000       1.000000       1.000000      25.000000
# 25%      2008.000000      24.000000   28138.000000    7425.000000
# 50%      2012.000000      35.000000   51086.000000   12300.000000
# 75%      2013.000000      41.000000   96591.000000   18300.000000
# max      2015.000000      49.000000  999999.000000  182000.000000
#
#         sellingprice
# count  472311.000000
# mean    13690.062179
# std      9612.314748
# min         1.000000
# 25%      7200.000000
# 50%     12200.000000
# 75%     18200.000000
# max    230000.000000

# %%
categories=['year','mmr','odometer','sellingprice','condition']
x[categories].median()
# Out:
# year             2012.0
# mmr             12300.0
# odometer        51086.0
# sellingprice    12200.0
# condition          35.0
# dtype: float64

# %%
st_graph=x[categories].std()
st_graph
# Out:
# year                3.822135
# mmr              9531.478251
# odometer        51939.434461
# sellingprice     9612.314748
# condition          13.286546
# dtype: float64

# %%
x[categories].mode()
# Out:
#    year    mmr  odometer  sellingprice  condition
# 0  2013  11650         1         12000         19

# %%
make_count=pd.value_counts(x['make'])
z=pd.DataFrame(make_count)
z
# Out:
# C:\Users\sbabh\AppData\Local\Temp\ipykernel_20396\1667438848.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   make_count=pd.value_counts(x['make'])
#                count
# make
# Ford           81012
# Chevrolet      54148
# Nissan         44042
# Toyota         35313
# Dodge          27181
# Honda          24781
# Hyundai        18659
# BMW            17506
# Kia            15824
# Chrysler       15133
# Infiniti       14011
# Mercedes-Benz  14008
# Jeep           12735
# Volkswagen     10780
# Lexus          10409
# GMC             9217
# Mazda           6930
# Cadillac        6315
# Lincoln         4926
# Audi            4800
# Acura           4503
# Buick           4470
# Subaru          4369
# Ram             4044
# Pontiac         4018
# Mitsubishi      3661
# Volvo           3081
# MINI            2946
# Saturn          2570
# Mercury         1571
# Scion           1545
# ...

# %%
# %matplotlib inline

# %%
plt.plot(a,b)

# %%
plt.plot(st_graph)
plt.show()

# %%
plt.plot(x[categories].median())

# %%
l=list(z.groupby('make'))
l
# Out:
# [('Acura',
#          count
#   make
#   Acura   4503),
#  ('Aston Martin',
#                 count
#   make
#   Aston Martin     24),
#  ('Audi',
#         count
#   make
#   Audi   4800),
#  ('BMW',
#         count
#   make
#   BMW   17506),
#  ('Bentley',
#            count
#   make
#   Bentley    105),
#  ('Buick',
#          count
#   make
#   Buick   4470),
#  ('Cadillac',
#             count
#   make
#   Cadillac   6315),
#  ('Chevrolet',
#              count
#   make
#   Chevrolet  54148),
#  ('Chrysler',
#             count
#   make
#   Chrysler  15133),
#  ('Daewoo',
#           count
#   make
#   Daewoo      2),
#  ('Dodge',
#          count
#   make
#   Dodge  27181),
#  ('FIAT',
#         count
#   make
#   FIAT    725),
#  ('Ferrari',
#            count
#   make
#   Ferrari     17),
#  ('Fisker',
#           count
#   make
#   Fisker      9),
#  ('Ford',
#         count
#   make
#   Ford  81012),
#  ('GMC',
#         count
#   make
#   GMC    9217),
#  ('Geo',
# ...

# %%
plt.title('Pie Chart')
plt.pie(make_count,labels=pd.value_counts(x['make']))
plt.show()
# Out:
# C:\Users\sbabh\AppData\Local\Temp\ipykernel_20396\2274913536.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   plt.pie(make_count,labels=pd.value_counts(x['make']))

# %%
plt.scatter(make_count,pd.value_counts(x['make']))
plt.show()
# Out:
# C:\Users\sbabh\AppData\Local\Temp\ipykernel_20396\4214629809.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   plt.scatter(make_count,pd.value_counts(x['make']))

# %%
plt.hist(x['year'])
plt.show()

# %%
plt.hist(x['sellingprice'])
plt.show()

# %%
feature=['year','make','model','odometer','condition']
n=x["sellingprice"]

k = x[feature]

# %%
x.dropna(inplace=True,ignore_index=True)

# %%
k
# Out:
#         year       make     model  odometer  condition
# 0       2015     Nissan    Altima     11398          2
# 1       2014       Audi        Q5      7983         49
# 2       2014  Chevrolet    Camaro     13441         17
# 3       2014        BMW  6 Series      8819         34
# 4       2015  Chevrolet    Impala     14538         19
# ...      ...        ...       ...       ...        ...
# 472306  2011        BMW  5 Series     66403         39
# 472307  2012        Ram      2500     54393          5
# 472308  2012        BMW        X5     50561         48
# 472309  2015     Nissan    Altima     16658         38
# 472310  2014       Ford     F-150     15008         34
#
# [472311 rows x 5 columns]

# %%
x.shape
# Out:
# (472311, 16)

# %%
x.isnull().sum()
# Out:
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# vin             0
# state           0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        0
# dtype: int64

# %%
import seaborn as sn

# %%
x.head()
# Out:
#    year       make     model                       trim         body  \
# 0  2015     Nissan    Altima                      2.5 S        Sedan
# 1  2014       Audi        Q5  2.0T Premium Plus quattro          SUV
# 2  2014  Chevrolet    Camaro                         LS        Coupe
# 3  2014        BMW  6 Series                       650i  Convertible
# 4  2015  Chevrolet    Impala                        LTZ        Sedan
#
#   transmission                vin state  condition  odometer   color interior  \
# 0    automatic  1n4al3ap5fc124223    ca          2     11398   black    black
# 1    automatic  wa1lfafpxea085074    ca         49      7983   white    black
# 2    automatic  2g1fa1e39e9134494    ca         17     13441   black    black
# 3    automatic  wbayp9c53ed169260    ca         34      8819   black    black
# 4    automatic  2g1165s30f9103921    ca         19     14538  silver    black
#
#                                               seller    mmr  sellingprice  \
# ...

# %%
sn.relplot(x='sellingprice',y='condition',data=x)

# %%
sn.relplot(x='sellingprice',y='odometer',data=x)

# %%
sn.relplot(x='sellingprice',y='year',hue='condition',data=x)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x.head()
# Out:
#    year       make     model                       trim         body  \
# 0  2015     Nissan    Altima                      2.5 S        Sedan
# 1  2014       Audi        Q5  2.0T Premium Plus quattro          SUV
# 2  2014  Chevrolet    Camaro                         LS        Coupe
# 3  2014        BMW  6 Series                       650i  Convertible
# 4  2015  Chevrolet    Impala                        LTZ        Sedan
#
#   transmission                vin state  condition  odometer   color interior  \
# 0    automatic  1n4al3ap5fc124223    ca          2     11398   black    black
# 1    automatic  wa1lfafpxea085074    ca         49      7983   white    black
# 2    automatic  2g1fa1e39e9134494    ca         17     13441   black    black
# 3    automatic  wbayp9c53ed169260    ca         34      8819   black    black
# 4    automatic  2g1165s30f9103921    ca         19     14538  silver    black
#
#                                               seller    mmr  sellingprice  \
# ...

# %%
train=x.drop(['saledate','state','trim','interior','seller'],axis=1)
test=x['sellingprice']
train.head()
train=train.drop(['vin','make','transmission','body','model','color','sellingprice'],axis=1)
train.head()
# Out:
#    year  condition  odometer    mmr
# 0  2015          2     11398  14750
# 1  2014         49      7983  37100
# 2  2014         17     13441  17750
# 3  2014         34      8819  68000
# 4  2015         19     14538  24300

# %%
x_train,x_test,y_train,y_test=train_test_split(train,test,test_size=0.2,random_state=2)

# %% [markdown]
# # Linear Regression

# %%
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predx=reg.predict(x_test)
predy=reg.predict(x_test)

# %% [markdown]
# # **Accuracy**

# %%
reg.score(x_test,y_test)
# Out:
# 0.9692915003852858

# %%
pd.get_dummies(x.head(20))
# Out:
#     year  condition  odometer    mmr  sellingprice  make_Audi  make_BMW  \
# 0   2015          2     11398  14750         14100      False     False
# 1   2014         49      7983  37100         40000       True     False
# 2   2014         17     13441  17750         17000      False     False
# 3   2014         34      8819  68000         67200      False      True
# 4   2015         19     14538  24300          7200      False     False
# 5   2014         29     25969  34200         30000      False      True
# 6   2015         49      5826  24000         23750       True     False
# 7   2014         38     10736  67000         65000      False      True
# 8   2015         42     16506  32100         32500      False     False
# 9   2015         48     12725  32300         32500      False     False
# 10  2014         42     11874  22200         19500      False     False
# 11  2014         42     37888  11600         11500      False     False
# ...
